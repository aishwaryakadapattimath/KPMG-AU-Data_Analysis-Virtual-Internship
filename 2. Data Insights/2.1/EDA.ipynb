# %% [markdown]
# We need to perform exploratory data analysis to gain insights into the distribution and relationships of the features in the dataset. We can use visualizations and statistical tests to identify any patterns or correlations that may be useful for modeling.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import warnings

sns.set_style('whitegrid')
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# We can merge the CustomerDemographic, CustomerAddress, and Transaction datasets to create a single, unified dataset.

# %%
df1 = pd.read_csv('C:\\Users\\aishw\\OneDrive\\Desktop\\KPMG Prj\\Task 1.1-Transactions.csv')
df3 = pd.read_csv('C:\\Users\\aishw\\OneDrive\\Desktop\\KPMG Prj\\Task 1.3-CustomerDemographic.csv')
df4 = pd.read_csv('C:\\Users\\aishw\\OneDrive\\Desktop\\KPMG Prj\\Task 1.4-CustomerAdress.csv')

# %%
df1.head(1)
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0            9785          72            1       2017-01-05           0.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved  Norco Bicycles     Standard        medium       medium
#
#    list_price  standard_cost        product_first_sold_date
# 0       360.4          270.3  1970-01-01 10:31:13.000000000

# %%
df2.head(1)
# Out:
#    Unnamed: 0 first_name last_name gender  \
# 0           0    Chickie   Brister   Male
#
#    past_3_years_bike_related_purchases         DOB        job_title  \
# 0                                   86  1957-07-12  General Manager
#
#   job_industry_category wealth_segment  deceased_indicator owns_car  tenure  \
# 0         Manufacturing  Mass Customer               False      Yes      14
#
#             address  postcode state    country  property_valuation  Rank  \
# 0  45 Shopko Center      4500   QLD  Australia                   6     1
#
#      Value
# 0  1.71875

# %%
df3.head(1)
# Out:
#    customer_id first_name  last_name  gender  \
# 0            1    Laraine  Medendorp  Female
#
#    past_3_years_bike_related_purchases                  DOB  \
# 0                                   93  1953-10-12 00:00:00
#
#              job_title job_industry_category wealth_segment  \
# 0  Executive Secretary                Health  Mass Customer
#
#    deceased_indicator  owns_car  tenure
# 0               False      True    11.0

# %%
df4.head(1)
# Out:
#    customer_id             address  postcode state    country  \
# 0            1  060 Morning Avenue      2016   NSW  Australia
#
#    property_valuation
# 0                  10

# %% [markdown]
# We can merge the customer demographic, customer address, and transaction datasets to create a single, unified dataset.

# %%
customers_df = df3.merge(df4, on='customer_id').merge(df1, on='customer_id')

# %%
customers_df
# Out:
#        customer_id first_name  last_name  gender  \
# 0                1    Laraine  Medendorp  Female
# 1                1    Laraine  Medendorp  Female
# 2                1    Laraine  Medendorp  Female
# 3                1    Laraine  Medendorp  Female
# 4                1    Laraine  Medendorp  Female
# ...            ...        ...        ...     ...
# 19963         3500       Josy    Fleeman  Female
# 19964         3500       Josy    Fleeman  Female
# 19965         3500       Josy    Fleeman  Female
# 19966         3500       Josy    Fleeman  Female
# 19967         3500       Josy    Fleeman  Female
#
#        past_3_years_bike_related_purchases                  DOB  \
# 0                                       93  1953-10-12 00:00:00
# 1                                       93  1953-10-12 00:00:00
# 2                                       93  1953-10-12 00:00:00
# 3                                       93  1953-10-12 00:00:00
# 4                                       93  1953-10-12 00:00:00
# ...                                    ...                  ...
# 19963                                   71  1967-07-21 00:00:00
# 19964                                   71  1967-07-21 00:00:00
# 19965                                   71  1967-07-21 00:00:00
# 19966                                   71  1967-07-21 00:00:00
# 19967                                   71  1967-07-21 00:00:00
#
#                                   job_title job_industry_category  \
# 0                       Executive Secretary                Health
# 1                       Executive Secretary                Health
# 2                       Executive Secretary                Health
# 3                       Executive Secretary                Health
# 4                       Executive Secretary                Health
# ...                                     ...                   ...
# 19963  Business Systems Development Analyst         Entertainment
# 19964  Business Systems Development Analyst         Entertainment
# 19965  Business Systems Development Analyst         Entertainment
# 19966  Business Systems Development Analyst         Entertainment
# 19967  Business Systems Development Analyst         Entertainment
#
#           wealth_segment  deceased_indicator  ...  transaction_date  \
# 0          Mass Customer               False  ...        2017-01-05
# 1          Mass Customer               False  ...        2017-02-21
# 2          Mass Customer               False  ...        2017-03-27
# 3          Mass Customer               False  ...        2017-03-29
# 4          Mass Customer               False  ...        2017-04-06
# ...                  ...                 ...  ...               ...
# 19963  Affluent Customer               False  ...        2017-01-11
# 19964  Affluent Customer               False  ...        2017-02-16
# 19965  Affluent Customer               False  ...        2017-03-14
# 19966  Affluent Customer               False  ...        2017-04-25
# 19967  Affluent Customer               False  ...        2017-08-08
#
#        online_order order_status           brand product_line product_class  \
# 0               0.0     Approved  Norco Bicycles     Standard        medium
# 1               0.0     Approved           Solex     Standard        medium
# 2               0.0     Approved  Norco Bicycles     Mountain           low
# 3               1.0     Approved  Giant Bicycles     Standard          high
# 4               1.0     Approved           Solex     Standard        medium
# ...             ...          ...             ...          ...           ...
# 19963           0.0     Approved        WeareA2B     Standard        medium
# 19964           0.0     Approved        WeareA2B     Standard        medium
# 19965           1.0     Approved      OHM Cycles     Standard          high
# 19966           0.0     Approved           Solex     Standard        medium
# 19967           0.0     Approved  Giant Bicycles     Standard        medium
#
#        product_size  list_price  standard_cost        product_first_sold_date
# 0            medium      360.40         270.30  1970-01-01 10:31:13.000000000
# 1            medium       71.49          53.62  1970-01-01 10:42:53.000000000
# 2             small      688.63         612.88  1970-01-01 09:17:35.000000000
# 3            medium     1274.93         764.96  1970-01-01 09:49:38.000000000
# 4            medium     1577.53         826.51  1970-01-01 10:58:46.000000000
# ...             ...         ...            ...                            ...
# 19963        medium       60.34          45.26  1970-01-01 09:29:25.000000000
# 19964        medium     1228.07         400.91  1970-01-01 10:11:08.000000000
# 19965        medium     1458.17         874.90  1970-01-01 10:45:50.000000000
# 19966        medium       71.49          53.62  1970-01-01 11:27:25.000000000
# 19967         small     1311.44        1167.18  1970-01-01 09:24:48.000000000
#
# [19968 rows x 29 columns]

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19968 entries, 0 to 19967
# Data columns (total 29 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          19968 non-null  int64
#  1   first_name                           19968 non-null  object
#  2   last_name                            19326 non-null  object
#  3   gender                               19968 non-null  object
#  4   past_3_years_bike_related_purchases  19968 non-null  int64
#  5   DOB                                  19968 non-null  object
#  6   job_title                            19968 non-null  object
#  7   job_industry_category                19968 non-null  object
#  8   wealth_segment                       19968 non-null  object
#  9   deceased_indicator                   19968 non-null  bool
#  10  owns_car                             19968 non-null  bool
#  11  tenure                               19968 non-null  float64
#  12  address                              19968 non-null  object
#  13  postcode                             19968 non-null  int64
#  14  state                                19968 non-null  object
#  15  country                              19968 non-null  object
#  16  property_valuation                   19968 non-null  int64
#  17  transaction_id                       19968 non-null  int64
#  18  product_id                           19968 non-null  int64
#  19  transaction_date                     19968 non-null  object
#  20  online_order                         19968 non-null  float64
#  21  order_status                         19968 non-null  object
#  22  brand                                19968 non-null  object
#  23  product_line                         19968 non-null  object
#  24  product_class                        19968 non-null  object
#  25  product_size                         19968 non-null  object
#  26  list_price                           19968 non-null  float64
#  27  standard_cost                        19968 non-null  float64
#  28  product_first_sold_date              19968 non-null  object
# dtypes: bool(2), float64(4), int64(6), object(17)
# memory usage: 4.2+ MB

# %%
customers_df['DOB']
# Out:
# 0        1953-10-12 00:00:00
# 1        1953-10-12 00:00:00
# 2        1953-10-12 00:00:00
# 3        1953-10-12 00:00:00
# 4        1953-10-12 00:00:00
#                 ...
# 19963    1967-07-21 00:00:00
# 19964    1967-07-21 00:00:00
# 19965    1967-07-21 00:00:00
# 19966    1967-07-21 00:00:00
# 19967    1967-07-21 00:00:00
# Name: DOB, Length: 19968, dtype: object

# %%
customers_df['DOB'] = pd.to_datetime(customers_df['DOB'], errors='coerce', infer_datetime_format=True)
customers_df['DOB'] = customers_df['DOB'].replace('NaT','')  # replace NaT with blank

# %%
customers_df['DOB']
# Out:
# 0       1953-10-12
# 1       1953-10-12
# 2       1953-10-12
# 3       1953-10-12
# 4       1953-10-12
#            ...
# 19963   1967-07-21
# 19964   1967-07-21
# 19965   1967-07-21
# 19966   1967-07-21
# 19967   1967-07-21
# Name: DOB, Length: 19968, dtype: datetime64[ns]

# %% [markdown]
# ### product_first_sold_date

# %%
customers_df['product_first_sold_date']
# Out:
# 0        1970-01-01 10:31:13.000000000
# 1        1970-01-01 10:42:53.000000000
# 2        1970-01-01 09:17:35.000000000
# 3        1970-01-01 09:49:38.000000000
# 4        1970-01-01 10:58:46.000000000
#                      ...
# 19963    1970-01-01 09:29:25.000000000
# 19964    1970-01-01 10:11:08.000000000
# 19965    1970-01-01 10:45:50.000000000
# 19966    1970-01-01 11:27:25.000000000
# 19967    1970-01-01 09:24:48.000000000
# Name: product_first_sold_date, Length: 19968, dtype: object

# %%
customers_df['product_first_sold_date'] = pd.to_datetime(customers_df['product_first_sold_date'], errors='coerce')

# %%
print(customers_df['product_first_sold_date'].head())
# Out:
# 0   1970-01-01 10:31:13
# 1   1970-01-01 10:42:53
# 2   1970-01-01 09:17:35
# 3   1970-01-01 09:49:38
# 4   1970-01-01 10:58:46
# Name: product_first_sold_date, dtype: datetime64[ns]

# %%
customers_df['product_first_sold_date'] = customers_df['product_first_sold_date'].dt.date

# %%
customers_df['product_first_sold_date'] = pd.to_datetime(customers_df['product_first_sold_date'])

# %%
customers_df['product_first_sold_date']
# Out:
# 0       1970-01-01
# 1       1970-01-01
# 2       1970-01-01
# 3       1970-01-01
# 4       1970-01-01
#            ...
# 19963   1970-01-01
# 19964   1970-01-01
# 19965   1970-01-01
# 19966   1970-01-01
# 19967   1970-01-01
# Name: product_first_sold_date, Length: 19968, dtype: datetime64[ns]

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19968 entries, 0 to 19967
# Data columns (total 29 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          19968 non-null  int64
#  1   first_name                           19968 non-null  object
#  2   last_name                            19326 non-null  object
#  3   gender                               19968 non-null  object
#  4   past_3_years_bike_related_purchases  19968 non-null  int64
#  5   DOB                                  19959 non-null  datetime64[ns]
#  6   job_title                            19968 non-null  object
#  7   job_industry_category                19968 non-null  object
#  8   wealth_segment                       19968 non-null  object
#  9   deceased_indicator                   19968 non-null  bool
#  10  owns_car                             19968 non-null  bool
#  11  tenure                               19968 non-null  float64
#  12  address                              19968 non-null  object
#  13  postcode                             19968 non-null  int64
#  14  state                                19968 non-null  object
#  15  country                              19968 non-null  object
#  16  property_valuation                   19968 non-null  int64
#  17  transaction_id                       19968 non-null  int64
#  18  product_id                           19968 non-null  int64
#  19  transaction_date                     19968 non-null  object
#  20  online_order                         19968 non-null  float64
#  21  order_status                         19968 non-null  object
#  22  brand                                19968 non-null  object
#  23  product_line                         19968 non-null  object
#  24  product_class                        19968 non-null  object
#  25  product_size                         19968 non-null  object
#  26  list_price                           19968 non-null  float64
#  27  standard_cost                        19968 non-null  float64
#  28  product_first_sold_date              19968 non-null  datetime64[ns]
# dtypes: bool(2), datetime64[ns](2), float64(4), int64(6), object(15)
# memory usage: 4.2+ MB

# %% [markdown]
# ### transaction_date

# %%
customers_df['transaction_date']
# Out:
# 0        2017-01-05
# 1        2017-02-21
# 2        2017-03-27
# 3        2017-03-29
# 4        2017-04-06
#             ...
# 19963    2017-01-11
# 19964    2017-02-16
# 19965    2017-03-14
# 19966    2017-04-25
# 19967    2017-08-08
# Name: transaction_date, Length: 19968, dtype: object

# %%
customers_df['transaction_date'] = pd.to_datetime(customers_df['transaction_date'])

# %%
customers_df['transaction_date']
# Out:
# 0       2017-01-05
# 1       2017-02-21
# 2       2017-03-27
# 3       2017-03-29
# 4       2017-04-06
#            ...
# 19963   2017-01-11
# 19964   2017-02-16
# 19965   2017-03-14
# 19966   2017-04-25
# 19967   2017-08-08
# Name: transaction_date, Length: 19968, dtype: datetime64[ns]

# %% [markdown]
# ### checking nulls

# %%
customers_df.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              642
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                      9
# job_title                                0
# job_industry_category                    0
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# transaction_id                           0
# product_id                               0
# transaction_date                         0
# online_order                             0
# order_status                             0
# brand                                    0
# product_line                             0
# product_class                            0
# product_size                             0
# list_price                               0
# standard_cost                            0
# product_first_sold_date                  0
# dtype: int64

# %%
customers_df['last_name'].fillna('', inplace = True)

# %%
customers_df['last_name'].isnull().sum()
# Out:
# 0

# %% [markdown]
# As mentioned in the tips lets change DOB column to a calculated age and age_class fields.

# %%
now = dt.datetime.now()
customers_df['age'] = (now-customers_df['DOB']).dt.days // 365

# %%
customers_df['DOB']
# Out:
# 0       1953-10-12
# 1       1953-10-12
# 2       1953-10-12
# 3       1953-10-12
# 4       1953-10-12
#            ...
# 19963   1967-07-21
# 19964   1967-07-21
# 19965   1967-07-21
# 19966   1967-07-21
# 19967   1967-07-21
# Name: DOB, Length: 19968, dtype: datetime64[ns]

# %%
customers_df['age']
# Out:
# 0        72.0
# 1        72.0
# 2        72.0
# 3        72.0
# 4        72.0
#          ...
# 19963    58.0
# 19964    58.0
# 19965    58.0
# 19966    58.0
# 19967    58.0
# Name: age, Length: 19968, dtype: float64

# %%
customers_df['age_class'] = round(customers_df['age']/10) * 10

# %%
customers_df['age_class'].value_counts()
# Out:
# age_class
# 50.0    6528
# 40.0    4078
# 60.0    3709
# 30.0    3152
# 70.0    2005
# 20.0     457
# 80.0      15
# 90.0      15
# Name: count, dtype: int64

# %%
# so Jephthah is 179 years old. 
customers_df[customers_df['age'] > 100]
# Out:
# Empty DataFrame
# Columns: [customer_id, first_name, last_name, gender, past_3_years_bike_related_purchases, DOB, job_title, job_industry_category, wealth_segment, deceased_indicator, owns_car, tenure, address, postcode, state, country, property_valuation, transaction_id, product_id, transaction_date, online_order, order_status, brand, product_line, product_class, product_size, list_price, standard_cost, product_first_sold_date, age, age_class]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# Univariate analysis:
# Analyze each feature separately to understand its distribution, range, and outliers.
#
# For categorical variables, we can plot bar charts or pie charts to show the frequency of each category.
#
# For continuous variables, we can plot histograms, boxplots, and density plots.

# %%
customers_df.head()
# Out:
#    customer_id first_name  last_name  gender  \
# 0            1    Laraine  Medendorp  Female
# 1            1    Laraine  Medendorp  Female
# 2            1    Laraine  Medendorp  Female
# 3            1    Laraine  Medendorp  Female
# 4            1    Laraine  Medendorp  Female
#
#    past_3_years_bike_related_purchases        DOB            job_title  \
# 0                                   93 1953-10-12  Executive Secretary
# 1                                   93 1953-10-12  Executive Secretary
# 2                                   93 1953-10-12  Executive Secretary
# 3                                   93 1953-10-12  Executive Secretary
# 4                                   93 1953-10-12  Executive Secretary
#
#   job_industry_category wealth_segment  deceased_indicator  ...  order_status  \
# 0                Health  Mass Customer               False  ...      Approved
# 1                Health  Mass Customer               False  ...      Approved
# 2                Health  Mass Customer               False  ...      Approved
# 3                Health  Mass Customer               False  ...      Approved
# 4                Health  Mass Customer               False  ...      Approved
#
#             brand product_line  product_class product_size list_price  \
# 0  Norco Bicycles     Standard         medium       medium     360.40
# 1           Solex     Standard         medium       medium      71.49
# 2  Norco Bicycles     Mountain            low        small     688.63
# 3  Giant Bicycles     Standard           high       medium    1274.93
# 4           Solex     Standard         medium       medium    1577.53
#
#    standard_cost  product_first_sold_date   age age_class
# 0         270.30               1970-01-01  72.0      70.0
# 1          53.62               1970-01-01  72.0      70.0
# 2         612.88               1970-01-01  72.0      70.0
# 3         764.96               1970-01-01  72.0      70.0
# 4         826.51               1970-01-01  72.0      70.0
#
# [5 rows x 31 columns]

# %%
# Let's see the gender distribution across the dataset
plt.figure(figsize=(10,6))
customers_df['gender'].value_counts().plot(kind='pie', autopct='%.2f', shadow=True)
plt.title('Gender distribution')
plt.savefig('Gender distribution-1.png')
plt.show()

# %%
plt.figure(figsize=(12, 6))
customers_df['age_class'].value_counts().sort_index().plot(kind='bar')
plt.title('Age group and value count')
plt.savefig('Age group and value count-1.png')
plt.show()

# %%
# customers by job industry
plt.figure(figsize=(12, 6))
sns.countplot(data=customers_df, x='job_industry_category')
plt.title('distribution of customer by job industry')
plt.savefig('distribution of customer by job industry-1.png')
plt.show()

# %%
plt.figure(figsize=(10, 6))
customers_df['wealth_segment'].value_counts().plot(kind='pie', autopct='%.2f', shadow=True)
plt.title('customer\'s Wealth segment')
plt.savefig('Customers wealth segment-1.png')
plt.show()

# %% [markdown]
# Bivariate or Multivariate analysis:
# Analyze the relationship between each pair or between three or more features to understand the correlations and associations.
#
# For continuous variables, you can plot scatterplots and correlation matrices.
#
# For categorical variables, you can plot contingency tables and heatmaps.

# %%
# Sales by month, I was just curious.
customers_df['transaction_date'].dt.strftime('%m').value_counts()
# Out:
# transaction_date
# 10    1768
# 08    1746
# 07    1715
# 05    1683
# 01    1679
# 11    1663
# 03    1652
# 04    1652
# 12    1643
# 02    1622
# 06    1579
# 09    1566
# Name: count, dtype: int64

# %%
# line plot shows total sales by month in 2017
plt.figure(figsize=(12, 6))
sns.lineplot(customers_df.groupby(customers_df['transaction_date'].dt.strftime('%B'))['transaction_id'].count())
plt.title('Sales by month')
plt.xlabel('Months')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# Spring - the three transition months September, October and November.
#
# Summer - the three hottest months December, January and February.
#
# Autumn - the transition months March, April and May.
#
# Winter - the three coldest months June, July and August.

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=customers_df, x='state', hue='gender')
plt.title('genders distribution by state')
plt.savefig('genders distribution by state-1.png')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=customers_df, x='wealth_segment', hue='gender')
plt.title('Wealth segment by genders')
plt.show()

# %%
plt.figure(figsize = (14,6))
sns.countplot(x='job_industry_category', data=customers_df, hue='gender')
plt.title('Job industry category across gender')
plt.show()

# %%
customers_df.to_csv('customer_df.csv', index=False)

# %%
df2 = pd.read_csv('C:\\Users\\aishw\\OneDrive\\Desktop\\KPMG Prj\\Task 1.2-NewCustomerList.csv')

# %%
df2.drop(df2.columns[0], axis=1, inplace=True)

# %%
df2.head(1)
# Out:
#   first_name last_name gender  past_3_years_bike_related_purchases  \
# 0    Chickie   Brister   Male                                   86
#
#           DOB        job_title job_industry_category wealth_segment  \
# 0  1957-07-12  General Manager         Manufacturing  Mass Customer
#
#    deceased_indicator owns_car  tenure           address  postcode state  \
# 0               False      Yes      14  45 Shopko Center      4500   QLD
#
#      country  property_valuation  Rank    Value
# 0  Australia                   6     1  1.71875

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  1000 non-null   object
#  5   job_title                            1000 non-null   object
#  6   job_industry_category                1000 non-null   object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   bool
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
#  11  address                              1000 non-null   object
#  12  postcode                             1000 non-null   int64
#  13  state                                1000 non-null   object
#  14  country                              1000 non-null   object
#  15  property_valuation                   1000 non-null   int64
#  16  Rank                                 1000 non-null   int64
#  17  Value                                1000 non-null   float64
# dtypes: bool(1), float64(1), int64(5), object(11)
# memory usage: 133.9+ KB

# %%
df2['DOB']
# Out:
# 0               1957-07-12
# 1               1970-03-22
# 2      1974-08-28 00:00:00
# 3               1979-01-28
# 4               1965-09-21
#               ...
# 995             1959-10-07
# 996             2001-10-17
# 997             1954-10-05
# 998             1952-12-17
# 999             1955-10-02
# Name: DOB, Length: 1000, dtype: object

# %%
customers_df['product_first_sold_date'] = customers_df['product_first_sold_date'].dt.date

# %%
df2['DOB'] = pd.to_datetime(df2['DOB'],errors='coerce', infer_datetime_format=True)

# %%
df2['DOB']
# Out:
# 0     1957-07-12
# 1     1970-03-22
# 2            NaT
# 3     1979-01-28
# 4     1965-09-21
#          ...
# 995   1959-10-07
# 996   2001-10-17
# 997   1954-10-05
# 998   1952-12-17
# 999   1955-10-02
# Name: DOB, Length: 1000, dtype: datetime64[ns]

# %%
df2['age'] = (dt.datetime.now() - df2['DOB']).dt.days // 365

# %%
# Let's create age class field
df2['age_class'] = round(df2['age']/10) * 100

# %%
df2['age'].fillna('')
# Out:
# 0      68.0
# 1      55.0
# 2
# 3      46.0
# 4      60.0
#        ...
# 995    66.0
# 996    23.0
# 997    71.0
# 998    72.0
# 999    70.0
# Name: age, Length: 1000, dtype: object

# %%
df2['age_class'].fillna('')
# Out:
# 0      700.0
# 1      600.0
# 2
# 3      500.0
# 4      600.0
#        ...
# 995    700.0
# 996    200.0
# 997    700.0
# 998    700.0
# 999    700.0
# Name: age_class, Length: 1000, dtype: object

# %%
df2['Value']
# Out:
# 0      1.718750
# 1      1.718750
# 2      1.718750
# 3      1.703125
# 4      1.703125
#          ...
# 995    0.374000
# 996    0.357000
# 997    0.357000
# 998    0.357000
# 999    0.340000
# Name: Value, Length: 1000, dtype: float64

# %%
df2['Value'] = df2['Value'].apply(lambda x : round(x, 2))

# %%
df2['Value']
# Out:
# 0      1.72
# 1      1.72
# 2      1.72
# 3      1.70
# 4      1.70
#        ...
# 995    0.37
# 996    0.36
# 997    0.36
# 998    0.36
# 999    0.34
# Name: Value, Length: 1000, dtype: float64

# %%
plt.figure(figsize=(10, 6))
df2['gender'].value_counts().plot(kind='pie', autopct='%.2f', shadow=True)
plt.title('Gender distribution')
plt.savefig('Gender distribution-2.png')
plt.show()

# %%
plt.figure(figsize=(12, 6))
df2['age_class'].value_counts().sort_index().plot(kind='bar')
plt.title('Age group and value count')
plt.savefig('Age group and value count-2.png')
plt.show()

# %%
# customers by job industry
plt.figure(figsize=(12, 6))
sns.countplot(data=df2, x='job_industry_category')
plt.title('distribution of customers by job industry')
plt.savefig('distribution of customers by job industry-2.png')
plt.show()

# %%
plt.figure(figsize=(10, 6))
df2['wealth_segment'].value_counts().plot(kind='pie', autopct='%.2f', shadow=True)
plt.title('customer\'s Wealth segment')
plt.savefig('Customers wealth segment-2.png')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df2, x='wealth_segment', hue='gender')
plt.title('Wealth segment by genders')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df2, x='state', hue='gender')
plt.title('genders distribution by state')
plt.savefig('genders distribution by state-2.png')
plt.show()

# %%
# customers by job industry
plt.figure(figsize=(12, 6))
sns.countplot(data=df2, x='job_industry_category', hue='gender')
plt.title('job industry across genders')
plt.show()

# %%
df2.to_csv('NewCustomer.csv', index=False)
